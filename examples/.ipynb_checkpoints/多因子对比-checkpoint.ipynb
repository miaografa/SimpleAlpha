# %% [markdown]
# <center><font size=5>单因子示例</font></center>

# %% [markdown]
# 目前只有IC相关的计算。余下的有待大家探索。

# %% [markdown]
# 加载各种包

# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('..')  # 文件位于

import factors  # 因子计算
import data_utils  # 数据读取
import performance as perf  # IC计算
import plotting  #绘图
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 1. 初始化DataLoader

# %% [markdown]
# DataLoader实现了对csv文件的批量读取，会按照\[年\]\[月\]保存在dl中。
# 一些重要函数：
# - init_month_df: 加载目标文件夹下的所有zip文件。这些文件读取后会被保存在dataloader中。注意，

# %%
dl = data_utils.DataLoader()
dl.init_month_df('../../data/15m_data/')
# 计算未来收益率
data_utils.compute_future_rtn_for_all(dl)

# %%
import pandas as pd
import numpy as np
from pandas_ta.core import macd, rsi, atr, vwap, ohlc4, bop

# %%
def cal_Z_score(factor_df, column_lists, span):
    '''Z-score'''

    for column_name in column_lists:
        mean_20 = factor_df[column_name].ewm(span, adjust=False).mean()
        std_20 = factor_df[column_name].ewm(96, adjust=False).std()  # todo 超参数搜索
        factor_df[f'{column_name}_Z'] = (factor_df[column_name].values - mean_20) / std_20

    return factor_df

# %%
from pandas_ta.core import adx, cci, macd, rsi, obv, vwap, atr, bop, ohlc4

# %%
@factors.handle_dataloader_data
def add_new_factor(raw_df:pd.DataFrame, z_targets)-> pd.DataFrame:
    '''
    加入新因子的模板。
    :param raw_df: 原始数据
    :param factor_name: 因子名称
    :return: 原始数据+因子
    '''
    data_df = raw_df[['open', 'close', 'high', 'low', 'volume']]
    data_df.index = pd.to_datetime(raw_df.open_time, unit='ms')
    temp_factor_df = pd.DataFrame()  # 暂存特征，避免index不一致导致的错误
    temp_factor_df['trend_adx'] = adx(data_df['high'], data_df['low'], data_df['close'])['ADX_14']
    temp_factor_df['trend_cci'] = cci(data_df['high'], data_df['low'], data_df['close'])
    temp_factor_df['macd'] = macd(data_df['close'])['MACD_12_26_9']
    temp_factor_df['momentum_rsi'] = rsi(data_df['close'])
    temp_factor_df['volume_obv'] = obv(data_df['close'], data_df['volume'])
    temp_factor_df['volume_vwap'] = vwap(data_df['high'], data_df['low'], data_df['close'], data_df['volume'])
    temp_factor_df['volatility_atr'] = atr(data_df['high'], data_df['low'], data_df['close'])
    temp_factor_df['bop'] = bop(data_df['open'], data_df['high'], data_df['low'],
                            data_df['close'])  # (open - close)/(high - low)
    temp_factor_df['ohlc4'] = ohlc4(data_df['open'], data_df['high'], data_df['low'], data_df['close'])
    temp_factor_df.reset_index(drop=True, inplace=True)
    raw_df = pd.concat([raw_df, temp_factor_df], axis=1)
    
    
    cal_Z_score(raw_df,z_targets, 30)
#     raw_df['bw_rtn_10'] = raw_df['fwd_rtn_10'].shift(10)

    return raw_df

# %%
z_targets = ['close', 'trend_adx', 'trend_cci', 'macd', 'momentum_rsi', \
                        'volume_obv', 'volume_vwap', 'volatility_atr', \
                        'bop', 'ohlc4', 'volume']

# %%
Z_cols = [f'{col}_Z' for col in z_targets]

# %%
# 计算因子
add_new_factor(dl, z_targets)

# %% [raw]
# pd.Series(np.arange(10)).pct_change().shift(1)

# %%
# plotting.plot_ic_qq(month_mean_ic)
# plotting.plot_ic_ts(month_mean_ic)
# plotting.plot_ic_hist(month_mean_ic)
# plt.show()

# %%
for colname in z_targets:
    for col in [colname +'_Z', colname]:
        print(f'feat name: {col}')
        tests_factor_name = col
        # 计算因子IC
        month_mean_ic = perf.cal_monthly_mean_ic(dl, factor_name=tests_factor_name, use_real_rtn=True)
        # 保存记录
        dl.set_record_df(kind='Info', factor_name=tests_factor_name, result_df=month_mean_ic)
        # 读取记录，并且展示作图
        month_mean_ic = dl.get_record_df(kind='Info', factor_name=tests_factor_name)
        plotting.plot_information_table(month_mean_ic)
# Out:
# feat name: close_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.044          -0.092           -0.115
# IC Std.                    0.015           0.023            0.027
# Risk-Adjusted IC          -2.848          -3.999           -4.301
# t-stat(IC)               -19.103         -26.824          -28.850
# p-value(IC)                0.000           0.000            0.000
# IC Skew                    0.116           0.288            0.167
# IC Kurtosis               -0.734          -1.126           -1.054
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.132           -0.135            -0.139
# IC Std.                     0.033            0.050             0.060
# Risk-Adjusted IC           -4.016           -2.715            -2.319
# t-stat(IC)                -26.942          -18.212           -15.554
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.176            0.300            -0.109
# IC Kurtosis                -0.729           -0.367            -0.515
# feat name: close
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.040          -0.084           -0.113
# IC Std.                    0.010           0.018            0.024
# Risk-Adjusted IC          -4.168          -4.600           -4.684
# t-stat(IC)               -27.957         -30.855          -31.423
# p-value(IC)                0.000           0.000            0.000
# IC Skew                   -0.285           0.125            0.034
# IC Kurtosis               -0.716          -0.352           -0.706
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.152           -0.225            -0.298
# IC Std.                     0.034            0.052             0.070
# Risk-Adjusted IC           -4.513           -4.348            -4.264
# t-stat(IC)                -30.273          -29.171           -28.606
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.076            0.136             0.187
# IC Kurtosis                -0.783           -0.535            -0.295
# feat name: trend_adx_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                    0.001           0.001            0.001
# IC Std.                    0.010           0.019            0.026
# Risk-Adjusted IC           0.071           0.074            0.043
# t-stat(IC)                 0.474           0.499            0.289
# p-value(IC)                0.638           0.620            0.774
# IC Skew                    0.405           0.573            0.851
# IC Kurtosis                0.422           0.504            1.052
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                     0.000           -0.005            -0.002
# IC Std.                     0.036            0.036             0.029
# Risk-Adjusted IC            0.008           -0.143            -0.085
# t-stat(IC)                  0.053           -0.960            -0.569
# p-value(IC)                 0.958            0.342             0.572
# IC Skew                     0.710           -0.028             0.225
# IC Kurtosis                 1.350           -0.493            -0.330
# feat name: trend_adx
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                    0.001           0.003            0.004
# IC Std.                    0.010           0.016            0.022
# Risk-Adjusted IC           0.121           0.208            0.181
# t-stat(IC)                 0.809           1.394            1.214
# p-value(IC)                0.423           0.170            0.231
# IC Skew                   -0.720          -0.143            0.080
# IC Kurtosis                1.566           0.088           -0.273
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                     0.005            0.008             0.013
# IC Std.                     0.029            0.035             0.045
# Risk-Adjusted IC            0.178            0.215             0.282
# t-stat(IC)                  1.193            1.444             1.889
# p-value(IC)                 0.239            0.156             0.065
# IC Skew                    -0.045            0.149             0.646
# IC Kurtosis                -0.650           -0.528             1.205
# feat name: trend_cci_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.046          -0.111           -0.124
# IC Std.                    0.018           0.023            0.027
# Risk-Adjusted IC          -2.561          -4.715           -4.574
# t-stat(IC)               -17.182         -31.626          -30.682
# p-value(IC)                0.000           0.000            0.000
# IC Skew                   -0.132          -0.213           -0.230
# IC Kurtosis               -0.589          -0.647           -0.322
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.116           -0.089            -0.060
# IC Std.                     0.028            0.020             0.018
# Risk-Adjusted IC           -4.192           -4.445            -3.351
# t-stat(IC)                -28.124          -29.819           -22.481
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.288            0.446             0.597
# IC Kurtosis                 0.278           -0.138            -0.009
# feat name: trend_cci
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.052          -0.122           -0.143
# IC Std.                    0.018           0.024            0.028
# Risk-Adjusted IC          -2.840          -5.018           -5.172
# t-stat(IC)               -19.050         -33.661          -34.697
# p-value(IC)                0.000           0.000            0.000
# IC Skew                   -0.069          -0.047           -0.022
# IC Kurtosis               -0.618          -0.839           -0.514
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.143           -0.120            -0.096
# IC Std.                     0.027            0.023             0.026
# Risk-Adjusted IC           -5.304           -5.176            -3.697
# t-stat(IC)                -35.583          -34.724           -24.803
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.331            0.075             0.292
# IC Kurtosis                 0.096           -0.872            -0.137
# feat name: macd_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.031          -0.066           -0.092
# IC Std.                    0.011           0.019            0.024
# Risk-Adjusted IC          -2.845          -3.401           -3.752
# t-stat(IC)               -19.087         -22.813          -25.166
# p-value(IC)                0.000           0.000            0.000
# IC Skew                    0.364           0.644            0.784
# IC Kurtosis               -0.408          -0.451            0.374
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.111           -0.097            -0.080
# IC Std.                     0.032            0.041             0.042
# Risk-Adjusted IC           -3.414           -2.385            -1.935
# t-stat(IC)                -22.903          -15.999           -12.978
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.476           -0.209             0.467
# IC Kurtosis                 0.347           -0.434            -0.089
# feat name: macd
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.032          -0.067           -0.095
# IC Std.                    0.011           0.019            0.024
# Risk-Adjusted IC          -2.860          -3.442           -3.941
# t-stat(IC)               -19.186         -23.092          -26.438
# p-value(IC)                0.000           0.000            0.000
# IC Skew                    0.594           0.495            0.404
# IC Kurtosis               -0.148          -0.325           -0.519
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.121           -0.130            -0.139
# IC Std.                     0.031            0.044             0.050
# Risk-Adjusted IC           -3.880           -2.973            -2.776
# t-stat(IC)                -26.025          -19.943           -18.619
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.392            0.630             0.258
# IC Kurtosis                -0.763           -0.115            -0.383
# feat name: momentum_rsi_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.056          -0.119           -0.136
# IC Std.                    0.019           0.025            0.028
# Risk-Adjusted IC          -2.885          -4.840           -4.920
# t-stat(IC)               -19.355         -32.465          -33.008
# p-value(IC)                0.000           0.000            0.000
# IC Skew                   -0.120          -0.052            0.203
# IC Kurtosis               -0.294          -0.592           -0.291
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.137           -0.110            -0.079
# IC Std.                     0.029            0.032             0.032
# Risk-Adjusted IC           -4.728           -3.405            -2.484
# t-stat(IC)                -31.720          -22.845           -16.660
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.634            0.352             0.575
# IC Kurtosis                -0.304           -0.536            -0.406
# feat name: momentum_rsi
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.057          -0.120           -0.145
# IC Std.                    0.019           0.025            0.028
# Risk-Adjusted IC          -3.060          -4.759           -5.137
# t-stat(IC)               -20.524         -31.925          -34.461
# p-value(IC)                0.000           0.000            0.000
# IC Skew                    0.051           0.189            0.324
# IC Kurtosis               -0.497          -1.011           -0.635
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.157           -0.145            -0.134
# IC Std.                     0.030            0.038             0.045
# Risk-Adjusted IC           -5.214           -3.773            -2.973
# t-stat(IC)                -34.978          -25.310           -19.941
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.381            0.459             0.337
# IC Kurtosis                -0.416           -0.114            -0.113
# feat name: volume_obv_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.030          -0.065           -0.083
# IC Std.                    0.011           0.018            0.022
# Risk-Adjusted IC          -2.807          -3.721           -3.832
# t-stat(IC)               -18.827         -24.959          -25.706
# p-value(IC)                0.000           0.000            0.000
# IC Skew                    0.461           0.525            0.380
# IC Kurtosis               -0.754          -0.701           -0.951
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.098           -0.106            -0.111
# IC Std.                     0.027            0.040             0.050
# Risk-Adjusted IC           -3.638           -2.660            -2.197
# t-stat(IC)                -24.402          -17.846           -14.736
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.281           -0.010            -0.319
# IC Kurtosis                -1.129           -0.565            -0.287
# feat name: volume_obv
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.031          -0.061           -0.081
# IC Std.                    0.008           0.015            0.021
# Risk-Adjusted IC          -3.963          -4.050           -3.888
# t-stat(IC)               -26.585         -27.168          -26.078
# p-value(IC)                0.000           0.000            0.000
# IC Skew                   -0.550          -0.232           -0.340
# IC Kurtosis               -0.019           0.319            0.557
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.109           -0.163            -0.217
# IC Std.                     0.029            0.044             0.059
# Risk-Adjusted IC           -3.743           -3.719            -3.675
# t-stat(IC)                -25.107          -24.945           -24.649
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                    -0.125           -0.079             0.104
# IC Kurtosis                 0.289            0.326             1.194
# feat name: volume_vwap_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.014          -0.031           -0.046
# IC Std.                    0.011           0.019            0.025
# Risk-Adjusted IC          -1.313          -1.656           -1.852
# t-stat(IC)                -8.808         -11.109          -12.423
# p-value(IC)                0.000           0.000            0.000
# IC Skew                    0.240           0.381            0.235
# IC Kurtosis               -0.475          -0.793           -0.989
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.066           -0.088            -0.107
# IC Std.                     0.035            0.055             0.063
# Risk-Adjusted IC           -1.893           -1.611            -1.681
# t-stat(IC)                -12.702          -10.808           -11.278
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.141           -0.338            -0.290
# IC Kurtosis                -1.019           -0.484            -0.607
# feat name: volume_vwap
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.029          -0.062           -0.086
# IC Std.                    0.008           0.015            0.021
# Risk-Adjusted IC          -3.597          -4.036           -4.049
# t-stat(IC)               -24.127         -27.077          -27.162
# p-value(IC)                0.000           0.000            0.000
# IC Skew                   -0.321           0.081           -0.057
# IC Kurtosis               -1.017          -0.601           -0.731
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.123           -0.196            -0.266
# IC Std.                     0.031            0.051             0.068
# Risk-Adjusted IC           -3.948           -3.864            -3.925
# t-stat(IC)                -26.485          -25.924           -26.327
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                    -0.055            0.083             0.123
# IC Kurtosis                -0.734           -0.385            -0.175
# feat name: volatility_atr_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.001          -0.001           -0.004
# IC Std.                    0.014           0.023            0.031
# Risk-Adjusted IC          -0.058          -0.053           -0.120
# t-stat(IC)                -0.388          -0.355           -0.804
# p-value(IC)                0.700           0.724            0.426
# IC Skew                   -0.026           0.115            0.251
# IC Kurtosis               -0.621           0.455            0.906
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.006           -0.009            -0.006
# IC Std.                     0.040            0.044             0.036
# Risk-Adjusted IC           -0.151           -0.205            -0.171
# t-stat(IC)                 -1.012           -1.376            -1.144
# p-value(IC)                 0.317            0.176             0.259
# IC Skew                     0.331            0.150             0.885
# IC Kurtosis                 0.274           -0.945             0.976
# feat name: volatility_atr
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.006          -0.010           -0.014
# IC Std.                    0.010           0.017            0.022
# Risk-Adjusted IC          -0.652          -0.586           -0.616
# t-stat(IC)                -4.372          -3.934           -4.129
# p-value(IC)                0.000           0.000            0.000
# IC Skew                    0.391           0.454            0.526
# IC Kurtosis                0.456           0.240            0.608
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.018           -0.027            -0.040
# IC Std.                     0.032            0.063             0.098
# Risk-Adjusted IC           -0.581           -0.426            -0.406
# t-stat(IC)                 -3.899           -2.860            -2.725
# p-value(IC)                 0.000            0.006             0.009
# IC Skew                     0.906            0.416            -0.119
# IC Kurtosis                 1.198            0.445            -0.262
# feat name: bop_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.045          -0.090           -0.076
# IC Std.                    0.028           0.020            0.017
# Risk-Adjusted IC          -1.596          -4.412           -4.578
# t-stat(IC)               -10.705         -29.598          -30.711
# p-value(IC)                0.000           0.000            0.000
# IC Skew                   -0.138           0.036           -0.089
# IC Kurtosis               -0.722          -0.436           -0.630
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.057           -0.038            -0.024
# IC Std.                     0.013            0.010             0.010
# Risk-Adjusted IC           -4.236           -3.720            -2.513
# t-stat(IC)                -28.414          -24.956           -16.856
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                    -0.148            0.045            -0.253
# IC Kurtosis                -0.436           -0.219            -0.051
# feat name: bop
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.049          -0.097           -0.085
# IC Std.                    0.029           0.021            0.017
# Risk-Adjusted IC          -1.682          -4.572           -4.887
# t-stat(IC)               -11.281         -30.668          -32.782
# p-value(IC)                0.000           0.000            0.000
# IC Skew                   -0.156           0.009           -0.073
# IC Kurtosis               -0.656          -0.570           -0.720
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.067           -0.048            -0.036
# IC Std.                     0.014            0.010             0.010
# Risk-Adjusted IC           -4.837           -4.686            -3.718
# t-stat(IC)                -32.448          -31.436           -24.944
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                    -0.021            0.079             0.009
# IC Kurtosis                -0.422           -0.778            -0.752
# feat name: ohlc4_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.036          -0.079           -0.105
# IC Std.                    0.013           0.021            0.025
# Risk-Adjusted IC          -2.749          -3.806           -4.158
# t-stat(IC)               -18.439         -25.533          -27.893
# p-value(IC)                0.000           0.000            0.000
# IC Skew                    0.201           0.287            0.149
# IC Kurtosis               -1.034          -1.134           -1.063
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.125           -0.130            -0.136
# IC Std.                     0.032            0.049             0.060
# Risk-Adjusted IC           -3.864           -2.636            -2.280
# t-stat(IC)                -25.923          -17.683           -15.294
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.178            0.305            -0.109
# IC Kurtosis                -0.715           -0.378            -0.511
# feat name: ohlc4
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                   -0.038          -0.080           -0.109
# IC Std.                    0.010           0.018            0.024
# Risk-Adjusted IC          -3.944          -4.498           -4.611
# t-stat(IC)               -26.456         -30.171          -30.933
# p-value(IC)                0.000           0.000            0.000
# IC Skew                   -0.331           0.119            0.038
# IC Kurtosis               -0.713          -0.406           -0.738
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.149           -0.222            -0.296
# IC Std.                     0.033            0.051             0.070
# Risk-Adjusted IC           -4.472           -4.332            -4.253
# t-stat(IC)                -29.997          -29.063           -28.532
# p-value(IC)                 0.000            0.000             0.000
# IC Skew                     0.071            0.138             0.189
# IC Kurtosis                -0.801           -0.540            -0.291
# feat name: volume_Z
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                    0.004           0.004           -0.000
# IC Std.                    0.011           0.012            0.014
# Risk-Adjusted IC           0.360           0.344           -0.027
# t-stat(IC)                 2.415           2.306           -0.179
# p-value(IC)                0.020           0.026            0.859
# IC Skew                    0.519          -0.360           -0.458
# IC Kurtosis               -0.336          -0.343           -0.886
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.005           -0.010            -0.008
# IC Std.                     0.020            0.026             0.021
# Risk-Adjusted IC           -0.247           -0.375            -0.388
# t-stat(IC)                 -1.660           -2.518            -2.603
# p-value(IC)                 0.104            0.015             0.013
# IC Skew                    -0.282           -0.174            -0.475
# IC Kurtosis                -0.171           -0.798            -0.090
# feat name: volume
# Information Analysis
#                   fwd_rtn_1_real  fwd_rtn_5_real  fwd_rtn_10_real  \
# IC Mean                    0.002           0.002           -0.002
# IC Std.                    0.012           0.012            0.015
# Risk-Adjusted IC           0.135           0.167           -0.129
# t-stat(IC)                 0.904           1.117           -0.866
# p-value(IC)                0.371           0.270            0.391
# IC Skew                    0.098          -0.428           -0.217
# IC Kurtosis               -0.938          -0.014           -0.556
#
#                   fwd_rtn_20_real  fwd_rtn_50_real  fwd_rtn_100_real
# IC Mean                    -0.006           -0.010            -0.012
# IC Std.                     0.020            0.034             0.051
# Risk-Adjusted IC           -0.315           -0.304            -0.242
# t-stat(IC)                 -2.112           -2.040            -1.624
# p-value(IC)                 0.040            0.047             0.112
# IC Skew                    -0.052            0.468            -0.156
# IC Kurtosis                -1.017           -0.634            -0.047
